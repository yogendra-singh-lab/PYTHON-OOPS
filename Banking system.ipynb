# %%
class User:
    def __init__(self,name, age,gender):
        self.name = name
        self.gender = gender
        self.age = age
    def show_details(self):
        print("Name of the user:" + self.name)
        print("age",self.age)
        print("gender of the user:"+ self.gender)
class Bank(User):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)
        self.total_balance = 0
    def deposit(self):
        amount = int(input("Enter the amount to be deposited :"))
        if amount <100:
            print("Minimum deposition amount should be greater than 100rs")
        else:
            self.total_balance = self.total_balance + amount 
            print("amount is deposited")
            print("total balance of your account is:",self.total_balance)
    def withdrawn(self):
        amount = int(input("Enter the amount you want to withdraw"))
        if self.total_balance>amount:
            if amount<100:
                print("minimum withdrawn limit is greater than 100rs:")
            else:
                print("your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!")
                self.total_balance = self.total_balance- amount
                print("total avail balance is : " ,self.total_balance)
        else:
            print("sorry you dont have required amount in your account")
            print("DON'T FORGET TO PUT ON YOUR MASK !")
    def checkbalance(self):
        print(" total balance is:" ,self.total_balance)
        if self.total_balance == 0:
            print("Warning!: your account has negative balance please deposit some amount to keep your account working")
u = Bank("yogendra",21,"male")
while(True):
        print("WELCOME TO SHEKHAWAT BANK")
        print("Choose your funtion")
        print("1.show_details")
        print("2.deposit")
        print("3.withdraw")
        print("4.checkbalance")
        choice = int(input())
        if choice == 1:
            u.show_details()
        elif choice == 2:
            u.deposit()
        elif choice == 3 : 
            u.withdrawn()
        elif choice == 4:
            u.checkbalance()
        else:
            print("wrong entry")
        print("press c to continue and q to exit")
        choice2 = input()
        if choice2 == "c":
            continue
        elif choice == "q":
            exit()
        
        
u = Bank("yogendra",21,"male")
# Out:
# WELCOME TO SHEKHAWAT BANK
# Choose your funtion
# 1.show_details
# 2.deposit
# 3.withdraw
# 4.checkbalance
# 1
# Name of the user:yogendra
# age 21
# gender of the user:male
# press c to continue and q to exit
# c
# WELCOME TO SHEKHAWAT BANK
# Choose your funtion
# 1.show_details
# 2.deposit
# 3.withdraw
# 4.checkbalance
# 2
# Enter the amount to be deposited :799
# amount is deposited
# total balance of your account is: 799
# press c to continue and q to exit
# c
# WELCOME TO SHEKHAWAT BANK
# Choose your funtion
# 1.show_details
# 2.deposit
# 3.withdraw
# 4.checkbalance
# 3
# Enter the amount you want to withdraw500
# your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!
# total avail balance is :  299
# press c to continue and q to exit
# c
# WELCOME TO SHEKHAWAT BANK
# Choose your funtion
# 1.show_details
# 2.deposit
# 3.withdraw
# 4.checkbalance
# 4
#  total balance is: 299
# press c to continue and q to exit

# %%
class User:
    def __init__(self,name, age,gender):
        self.name = name
        self.gender = gender
        self.age = age
    def show_details(self):
        print("Name of the user:" + self.name)
        print("Age of the user:" + self.age)
        print("gender of the user:"+ self.gender)
class Bank(User):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)
        
    def deposit(self):
        amount = int("Enter the amount to be deposited :")
        if amount <100:
            print("Minimum deposition amount should be greater than 100rs")
        else:
            total_balance = total_balance + amount 
            print("amount is deposited")
            print("total balance of your account is: "+ total_balance)
    def withdrawn(self):
        amount = int("Enter the amount you want to withdraw")
        if total_balance>amount:
            if amount<100:
                print("minimum withdrawn limit is greater than 100rs:")
            else:
                print("your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!")
                total_balance = total_balance- amount
                print("total avail balance is : " + total_balance)
        else:
            print("sorry you dont have required amount in your account")
            print("DON'T FORGET TO PUT ON YOUR MASK !")
    def checkbalance(self):
        print(" total balance is:" + total_balance)
        if total_balance == 0:
            print("Warning!: your account has negative balance please deposit some amount to keep your account working")
        
        
            
        
u = User("yogendra",21,"male")

# %%
class User:
    def __init__(self,name, age,gender):
        self.name = name
        self.gender = gender
        self.age = age
    def show_details(self):
        print("Name of the user:" + self.name)
        print(self.age)
        print("gender of the user:"+ self.gender)
class Bank(User):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)
        self.total_balance = 0
    def deposit(self):
        amount = int(input("Enter the amount to be deposited :"))
        if amount <100:
            print("Minimum deposition amount should be greater than 100rs")
        else:
            self.total_balance = self.total_balance + amount 
            print("amount is deposited")
            print("total balance of your account is:",self.total_balance)
    def withdrawn(self):
        amount = int(input("Enter the amount you want to withdraw"))
        if total_balance>amount:
            if amount<100:
                print("minimum withdrawn limit is greater than 100rs:")
            else:
                print("your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!")
                total_balance = total_balance- amount
                print("total avail balance is : " + total_balance)
        else:
            print("sorry you dont have required amount in your account")
            print("DON'T FORGET TO PUT ON YOUR MASK !")
        
u = Bank("yogendra",21,"male")
u.show_details()
u.withdraw()
