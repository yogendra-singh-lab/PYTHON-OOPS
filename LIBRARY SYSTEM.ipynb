# %%
class Library:
    def __init__(self,list,user):
        self.user = user
        self.list = list
        self.lendict = {}
    def showbook(self,list):
        print("following books are present in the library:")
        for book in self.list:
            print(book)
    def lendbook(self,user,book):
        if book not in self.lendict.keys():
            self.lendict.update({book:user})
            print("the book has been updated")
            
    def addbook(self,book):
        self.list.append(book)
        print("the book has been added to the list")
        
    def returnbook(self,book):
        self.lendict.remove(book)
yogi = Library(["the secret","the brave","shoot dive and fly","the alchemist","the subtle art of not giving a fuck","boots belts and berets"],"Yogendra")

while(True):
    print(f"welcome to the the {yogi.user} library. Enter your choice to continue")
    print("1. to display the all books")
    print("2.to lend a book")
    print("3.to add a book")
    print("4.to return a book")
    choice = int(input())
    if choice  == 1:
        yogi.showbook(list)
    elif choice == 2:
        book = input("enter the book name you want to lend")
        name = input("enter youtr name")
        yogi.lendbook(name,book)
    elif choice == 3:
        book = input("enter the book name you want to add")
        
        yogi.addbook(book)
    elif choice  == 4:
        book = ("enter the you want to return ")
        yogi.returnbook(book)
    else: 
        print("not a valid option")   
    print("press q to continue and c to exit")
    choice2 = input()
    if choice2 == "c":
        continue
    elif choice == "q":
        exit()
# Out:
# welcome to the the Yogendra library. Enter your choice to continue
# 1. to display the all books
# 2.to lend a book
# 3.to add a book
# 4.to return a book
# 2
# enter the book name you want to lendthe secret
# enter youtr namevinayak
# the book has been updated
# press q to continue and c to exit
# q
# welcome to the the Yogendra library. Enter your choice to continue
# 1. to display the all books
# 2.to lend a book
# 3.to add a book
# 4.to return a book
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-549f22332642> in <module>
#      40     elif choice  == 4:
#      41         book = ("enter the you want to return ")
# ---> 42         yogi.returnbook(book)
#      43     else:
#      44         print("not a valid option")
#
# <ipython-input-1-549f22332642> in returnbook(self, book)
#      18
#      19     def returnbook(self,book):
# ---> 20         self.lendict.remove(book)
#      21 yogi = Library(["the secret","the brave","shoot dive and fly","the alchemist","the subtle art of not giving a fuck","boots belts and berets"],"Yogendra")
#      22
#
# AttributeError: 'dict' object has no attribute 'remove'

# %%
class User:
    def __init__(self,name, age,gender):
        self.name = name
        self.gender = gender
        self.age = age
    def show_details(self):
        print("Name of the user:" + self.name)
        print(self.age)
        print("gender of the user:"+ self.gender)
class Bank(User):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)
        self.total_balance = 0
    def deposit(self):
        amount = int(input("Enter the amount to be deposited :"))
        if amount <100:
            print("Minimum deposition amount should be greater than 100rs")
        else:
            self.total_balance = self.total_balance + amount 
            print("amount is deposited")
            print("total balance of your account is:",self.total_balance)
    def withdraw(self):
        amount = int(input("Enter the amount you want to withdraw"))
        if self.total_balance>amount:
            if amount<100:
                print("minimum withdrawn limit is greater than 100rs:")
            else:
                print("your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!")
                self.total_balance = self.total_balance- amount
                print("total avail balance is : " + self.total_balance)
        else:
            print("sorry you dont have required amount in your account")
            print("DON'T FORGET TO PUT ON YOUR MASK !")
        
u = Bank("yogendra",21,"male")
u.show_details()
u.withdraw()
# Out:
# Name of the user:yogendra
# 21
# gender of the user:male
# Enter the amount you want to withdraw600
# sorry you dont have required amount in your account
# DON'T FORGET TO PUT ON YOUR MASK !

# %%
class User:
    def __init__(self,name, age,gender):
        self.name = name
        self.gender = gender
        self.age = age
    def show_details(self):
        print("Name of the user:" + self.name)
        print("age",self.age)
        print("gender of the user:"+ self.gender)
class Bank(User):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)
        self.total_balance = 0
    def deposit(self):
        amount = int(input("Enter the amount to be deposited :"))
        if amount <100:
            print("Minimum deposition amount should be greater than 100rs")
        else:
            self.total_balance = self.total_balance + amount 
            print("amount is deposited")
            print("total balance of your account is:",self.total_balance)
    def withdrawn(self):
        amount = int(input("Enter the amount you want to withdraw"))
        if self.total_balance>amount:
            if amount<100:
                print("minimum withdrawn limit is greater than 100rs:")
            else:
                print("your transaction is in process please wait.......... HOPE YOU HAVE PUT UP YOUR MASK!")
                self.total_balance = self.balance - amount
        else:
            print("sorry you dont have required amount in your account")
            print("DON'T FORGET TO PUT ON YOUR MASK !")
    def checkbalance(self):
        print(" total balance is:" ,self.total_balance)
        if self.total_balance == 0:
            print("Warning!: your account has negative balance please deposit some amount to keep your account working")
    while(True):
        print("WELCOME TO SHEKHAWAT BANK")
        print("Choose your funtion")
        print("1.show_details")
        print("2.deposit")
        print("3.withdraw")
        print("4.checkbalance")
        choice = int(input())
        if choice == 1:
            u.show_details()
        elif choice == 2:
            u.deposit()
        elif choice == 3 : 
            u.withdraw()
        elif choice == 4:
            u.checkbalance()
        else:
            print("wrong entry")
        print("press c to continue and q to exit")
        choice2 = input()
        if choice2 == "c":
            continue
        elif choice == "q":
            exit()
        
        
u = Bank("yogendra",21,"male")
